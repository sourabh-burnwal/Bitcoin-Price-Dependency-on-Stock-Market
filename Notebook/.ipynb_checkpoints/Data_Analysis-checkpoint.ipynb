# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
df = pd.read_csv('../Data/dataset_final.csv', parse_dates=['date'], index_col=['date'])
df = df.drop('Unnamed: 0', axis=1)
df.head()
# Out:
#             btc_price  gold_price  oil_wti_price  sp500_close  btc_num_trans  \
# date
# 2015-01-15     211.91      1352.8          46.37      1992.67       102309.0
# 2015-01-16     199.46      1364.9          48.49      2019.42       104699.0
# 2015-01-20     208.00      1377.4          46.79      2022.55        98485.0
# 2015-01-21     225.51      1378.4          47.85      2032.12        98485.0
# 2015-01-22     226.32      1390.2          45.93      2063.15        93698.0
#
#             btc_google_search    btc_dr   gold_dr    oil_dr  sp500_dr  \
# date
# 2015-01-15                  3  0.568670  0.021141 -0.044705 -0.009291
# 2015-01-16                  3 -0.060548  0.008905  0.044705  0.013335
# 2015-01-20                  3  0.041924  0.009116 -0.035688  0.001549
# 2015-01-21                  3  0.080826  0.000726  0.022402  0.004720
# 2015-01-22                  3  0.003585  0.008524 -0.040953  0.015154
#
#                 BVOL      GVOL      OVOL    VIX
# date
# 2015-01-15  0.853974  0.344132  0.344950  22.39
# 2015-01-16  0.857286  0.348453  0.346061  20.95
# 2015-01-20  0.857176  0.348518  0.346647  19.89
# 2015-01-21  0.893605  0.350149  0.347336  18.85
# 2015-01-22  0.904949  0.351242  0.343230  16.40

# %%
df.describe()
# Out:
#           btc_price   gold_price  oil_wti_price  sp500_close  btc_num_trans  \
# count   1319.000000  1319.000000    1319.000000  1319.000000    1319.000000
# mean    4207.428529  1339.761410      52.190212  2485.054284  244981.990902
# std     3979.274919   114.922904      10.437854   377.686923   77908.940627
# min      199.460000  1097.700000      12.170000  1829.080000   85232.000000
# 25%      454.935000  1270.250000      46.295000  2108.195000  197876.000000
# 50%     3429.950000  1324.100000      52.010000  2467.700000  244203.000000
# 75%     7386.775000  1391.600000      58.910000  2792.525000  304160.500000
# max    19039.000000  1768.900000      77.410000  3386.150000  439549.000000
#
#        btc_google_search       btc_dr      gold_dr       oil_dr     sp500_dr  \
# count        1319.000000  1319.000000  1319.000000  1319.000000  1319.000000
# mean           12.479909     0.003184     0.000205    -0.000502     0.000309
# std            14.691548     0.049275     0.009305     0.035535     0.011732
# min             2.000000    -0.491226    -0.071322    -0.281382    -0.127652
# 25%             3.000000    -0.013017    -0.003985    -0.013919    -0.003004
# 50%            10.000000     0.002677     0.000151     0.000424     0.000509
# 75%            15.000000     0.021938     0.004356     0.012658     0.004731
# max           100.000000     0.568670     0.067930     0.425832     0.089683
#
#               BVOL         GVOL         OVOL          VIX
# count  1319.000000  1319.000000  1319.000000  1319.000000
# mean      0.668588     0.145066     0.348608    16.189181
# std       0.296268     0.051615     0.244313     7.781896
# min       0.137440     0.065379     0.130754     9.140000
# 25%       0.434617     0.114385     0.226653    12.340000
# 50%       0.596028     0.129268     0.286633    14.120000
# 75%       0.913702     0.166734     0.368232    17.320000
# max       1.414832     0.371978     1.803450    82.690000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1319 entries, 2015-01-15 to 2020-04-27
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   btc_price          1319 non-null   float64
#  1   gold_price         1319 non-null   float64
#  2   oil_wti_price      1319 non-null   float64
#  3   sp500_close        1319 non-null   float64
#  4   btc_num_trans      1319 non-null   float64
#  5   btc_google_search  1319 non-null   int64
#  6   btc_dr             1319 non-null   float64
#  7   gold_dr            1319 non-null   float64
#  8   oil_dr             1319 non-null   float64
#  9   sp500_dr           1319 non-null   float64
#  10  BVOL               1319 non-null   float64
#  11  GVOL               1319 non-null   float64
#  12  OVOL               1319 non-null   float64
#  13  VIX                1319 non-null   float64
# dtypes: float64(13), int64(1)
# memory usage: 154.6 KB

# %% [markdown]
# # Plotting
# **A time series plot of your data and visually check if there are any obvious trends or seasonality.**

# %%
viz = df.columns.tolist()
print(viz)
# Out:
# ['btc_price', 'gold_price', 'oil_wti_price', 'sp500_close', 'btc_num_trans', 'btc_google_search', 'btc_dr', 'gold_dr', 'oil_dr', 'sp500_dr', 'BVOL', 'GVOL', 'OVOL', 'VIX']

# %%
for i in viz:
  ds = df[[i]]
  # Visualize the trends in data
  sns.set_style('darkgrid')
  fig, ax = plt.subplots(nrows=1, ncols=2, figsize = (20,10))
  ds.plot(kind = 'line', legend = 'reverse', title = 'Visualizing Sensor Array Time-Series', ax =ax[0])
  ds.plot(kind = 'hist', legend = 'reverse', title = 'Histogram of Time-Series', ax =ax[1])
  plt.legend(loc = 'upper right', shadow = True, bbox_to_anchor = (1.35, 0.8))
  plt.show()

# %% [markdown]
# # Lag Plot
# **Lag plots are used to check if a data set or time series is random. Random data should not exhibit any structure in the lag plot. Non-random structure implies that the underlying data are not random.**

# %%
from pandas.plotting import lag_plot


for i in viz:
  ds = df[[i]]
  # Visualize the trends in data
  sns.set_style('darkgrid')
  fig, ax = plt.subplots(nrows=1, ncols=3, figsize = (18,10))
  ds.plot(kind = 'line', legend = 'reverse', title = 'Visualizing Sensor Array Time-Series', ax =ax[0])
  ds.plot(kind = 'hist', legend = 'reverse', title = 'Histogram of Time-Series', ax =ax[1])
  lag_plot(ds, ax = ax[2])
  ax[2].set_title('lag_plot time series');
  plt.legend(loc = 'upper right', shadow = True, bbox_to_anchor = (1.35, 0.8))
  plt.show()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %% [markdown]
# # Statistical correlation summarizes the strength of the relationship between two variables.
#
# * A plot of the autocorrelation of a time series by lag is called the AutoCorrelation Function, or the acronym ACF. This plot is sometimes called a correlogram or an autocorrelation plot.
#
# * A partial autocorrelation is a summary of the relationship between an observation in a time series with observations at prior time steps with the relationships of intervening observations removed.

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

for i in viz:
  ds = df[[i]]
  # Visualize the trends in data
  sns.set_style('darkgrid')
  fig, ax = plt.subplots(nrows=1, ncols=2, figsize = (20,10))
  print(ds.columns.to_list())
  plot_acf(ds, ax=ax[0], lags = range(0,20))
  ax[0].set_title('ACF Time Series')
  plot_pacf(ds, ax=ax[1], lags = range(0,20))
  ax[1].set_title('PACF Time Series')
  plt.show()
# Out:
# ['btc_price']
# ['gold_price']
# ['oil_wti_price']
# ['sp500_close']
# ['btc_num_trans']
# ['btc_google_search']
# ['btc_dr']
# ['gold_dr']
# ['oil_dr']
# ['sp500_dr']
# ['BVOL']
# ['GVOL']
# ['OVOL']
# ['VIX']

# %% [markdown]
# # Statistical Test to Check If Variable is Time Dependent or not
#
# *  p-value > 0.05: Accept the null hypothesis (H0), the data has a unit root and is non-stationary.
# *  p-value <= 0.05: Reject the null hypothesis (H0), the data does not have a unit root and is stationary.

# %%
feature_range = (0, 1)
#scaler = MinMaxScaler(feature_range)
scaler = StandardScaler(with_mean=False, with_std=False)
scaled_data1 = scaler.fit_transform(df)

# %%
scaled_data1.T[1]
# Out:
# array([1352.8, 1364.9, 1377.4, ..., 1745.4, 1735.6, 1723.8])

# %%
from statsmodels.tsa.stattools import adfuller
for i,j in enumerate(viz):
  ds = df[[j]]
  X = scaled_data1.T[i].flatten()
  print(X)
  result = adfuller(X)
  print(f'Column name in dataset = {ds.columns}')
  print('ADF Statistic: %f' % result[0])
  print('p-value: %f' % result[1])
  print('Critical Values:')
  for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# [ 211.91  199.46  208.   ... 7488.83 7514.64 7789.77]
# Column name in dataset = Index(['btc_price'], dtype='object')
# ADF Statistic: -1.734156
# p-value: 0.413606
# Critical Values:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568
# [1352.8 1364.9 1377.4 ... 1745.4 1735.6 1723.8]
# Column name in dataset = Index(['gold_price'], dtype='object')
# ADF Statistic: -0.132431
# p-value: 0.946111
# Critical Values:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568
# [46.37 48.49 46.79 ... 15.06 15.99 12.17]
# Column name in dataset = Index(['oil_wti_price'], dtype='object')
# ADF Statistic: -0.438889
# p-value: 0.903401
# Critical Values:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568
# [1992.67 2019.42 2022.55 ... 2797.8  2836.74 2878.48]
# Column name in dataset = Index(['sp500_close'], dtype='object')
# ADF Statistic: -1.270888
# p-value: 0.642384
# Critical Values:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568
# [102309. 104699.  98485. ... 278755. 278755. 280805.]
# Column name in dataset = Index(['btc_num_trans'], dtype='object')
# ADF Statistic: -2.400896
# p-value: 0.141484
# Critical Values:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568
# [ 3.  3.  3. ... 16. 16. 16.]
# Column name in dataset = Index(['btc_google_search'], dtype='object')
# ADF Statistic: -2.771784
# p-value: 0.062419
# Critical Values:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568
# [ 0.56866991 -0.06054794  0.04192436 ...  0.04814248  0.00344054
#   0.03595822]
# Column name in dataset = Index(['btc_dr'], dtype='object')
# ADF Statistic: -19.709434
# p-value: 0.000000
# Critical Values:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568
# [ 0.02114149  0.00890465  0.0091165  ...  0.00407613 -0.00563058
#  -0.00682202]
# Column name in dataset = Index(['gold_dr'], dtype='object')
# ADF Statistic: -8.831972
# p-value: 0.000000
# Critical Values:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568
# [-0.04470489  0.04470489 -0.03568809 ...  0.09903557  0.0599213
#  -0.27298962]
# Column name in dataset = Index(['oil_dr'], dtype='object')
# ADF Statistic: -7.945615
# p-value: 0.000000
# Critical Values:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568
# [-0.00929092  0.01333489  0.00154875 ... -0.00053956  0.01382211
#   0.01460687]
# Column name in dataset = Index(['sp500_dr'], dtype='object')
# ADF Statistic: -8.262172
# p-value: 0.000000
# Critical Values:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568
# [0.85397399 0.85728627 0.85717583 ... 0.7102485  0.6681584  0.66176285]
# Column name in dataset = Index(['BVOL'], dtype='object')
# ADF Statistic: -4.212580
# p-value: 0.000627
# Critical Values:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568
# [0.34413192 0.34845315 0.34851796 ... 0.36217297 0.35159008 0.32440368]
# Column name in dataset = Index(['GVOL'], dtype='object')
# ADF Statistic: -3.303031
# p-value: 0.014744
# Critical Values:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568
# [0.34495024 0.34606088 0.34664696 ... 1.67877017 1.69290154 1.67803203]
# Column name in dataset = Index(['OVOL'], dtype='object')
# ADF Statistic: -0.247135
# p-value: 0.932665
# Critical Values:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568
# [22.39 20.95 19.89 ... 41.38 35.93 33.29]
# Column name in dataset = Index(['VIX'], dtype='object')
# ADF Statistic: -4.246086
# p-value: 0.000550
# Critical Values:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568

# %%
# Splitting the dataset into train & test subsets
n_obs = 1000
ds_train, ds_test = df[:-n_obs], df[-n_obs:]

# Augmented Dickey-Fuller Test (ADF Test) to check for stationarity
from statsmodels.tsa.stattools import adfuller

def adf_test(ds):
    dftest = adfuller(ds, autolag='AIC')
    adf = pd.Series(dftest[0:4], index = ['Test Statistic','p-value','# Lags','# Observations'])

    for key, value in dftest[4].items():
       adf['Critical Value (%s)'%key] = value
    print (adf)

    p = adf['p-value']
    if p <= 0.05:
        print("\nSeries is Stationary")
    else:
        print("\nSeries is Non-Stationary")


for i in ds_train.columns:
    print("Column: ",i)
    print('--------------------------------------')
    adf_test(ds_train[i])
    print('\n')

# Differencing all variables to get rid of Stationarity
ds_differenced = ds_train.diff().dropna()

# Running the ADF test once again to test for Stationarity
for i in ds_differenced.columns:
    print("Column: ",i)
    print('--------------------------------------')
    adf_test(ds_differenced[i])
    print('\n')

# Now cols: 3, 5, 6, 8 are non-stationary
ds_differenced = ds_differenced.diff().dropna()

# Running the ADF test for the 3rd time to test for Stationarity
for i in ds_differenced.columns:
    print("Column: ",i)
    print('--------------------------------------')
    adf_test(ds_differenced[i])
    print('\n')
# Out:
# Column:  btc_price
# --------------------------------------
# Test Statistic           -0.753110
# p-value                   0.832509
# # Lags                    0.000000
# # Observations          318.000000
# Critical Value (1%)      -3.451082
# Critical Value (5%)      -2.870672
# Critical Value (10%)     -2.571636
# dtype: float64
#
# Series is Non-Stationary
#
#
# Column:  gold_price
# --------------------------------------
# Test Statistic           -2.117823
# p-value                   0.237409
# # Lags                    1.000000
# # Observations          317.000000
# Critical Value (1%)      -3.451148
# Critical Value (5%)      -2.870701
# Critical Value (10%)     -2.571651
# dtype: float64
#
# Series is Non-Stationary
#
#
# Column:  oil_wti_price
# --------------------------------------
# Test Statistic           -1.413907
# p-value                   0.575591
# # Lags                    0.000000
# # Observations          318.000000
# Critical Value (1%)      -3.451082
# Critical Value (5%)      -2.870672
# Critical Value (10%)     -2.571636
# dtype: float64
#
# Series is Non-Stationary
#
#
# Column:  sp500_close
# --------------------------------------
# Test Statistic           -2.500191
# p-value                   0.115428
# # Lags                    0.000000
# # Observations          318.000000
# Critical Value (1%)      -3.451082
# Critical Value (5%)      -2.870672
# Critical Value (10%)     -2.571636
# dtype: float64
#
# Series is Non-Stationary
#
#
# Column:  btc_num_trans
# --------------------------------------
# Test Statistic           -1.493110
# p-value                   0.536917
# # Lags                    3.000000
# # Observations          315.000000
# Critical Value (1%)      -3.451281
# Critical Value (5%)      -2.870760
# Critical Value (10%)     -2.571682
# dtype: float64
#
# Series is Non-Stationary
#
#
# Column:  btc_google_search
# --------------------------------------
# Test Statistic           -2.129762
# p-value                   0.232717
# # Lags                    0.000000
# # Observations          318.000000
# Critical Value (1%)      -3.451082
# Critical Value (5%)      -2.870672
# Critical Value (10%)     -2.571636
# dtype: float64
#
# Series is Non-Stationary
#
#
# Column:  btc_dr
# --------------------------------------
# Test Statistic         -1.056843e+01
# p-value                 7.412455e-19
# # Lags                  2.000000e+00
# # Observations          3.160000e+02
# Critical Value (1%)    -3.451215e+00
# Critical Value (5%)    -2.870730e+00
# Critical Value (10%)   -2.571666e+00
# dtype: float64
#
# Series is Stationary
#
#
# Column:  gold_dr
# --------------------------------------
# Test Statistic          -22.506354
# p-value                   0.000000
# # Lags                    0.000000
# # Observations          318.000000
# Critical Value (1%)      -3.451082
# Critical Value (5%)      -2.870672
# Critical Value (10%)     -2.571636
# dtype: float64
#
# Series is Stationary
#
#
# Column:  oil_dr
# --------------------------------------
# Test Statistic          -19.059461
# p-value                   0.000000
# # Lags                    0.000000
# # Observations          318.000000
# Critical Value (1%)      -3.451082
# Critical Value (5%)      -2.870672
# Critical Value (10%)     -2.571636
# dtype: float64
#
# Series is Stationary
#
#
# Column:  sp500_dr
# --------------------------------------
# Test Statistic         -1.772193e+01
# p-value                 3.465215e-30
# # Lags                  0.000000e+00
# # Observations          3.180000e+02
# Critical Value (1%)    -3.451082e+00
# Critical Value (5%)    -2.870672e+00
# Critical Value (10%)   -2.571636e+00
# dtype: float64
#
# Series is Stationary
#
#
# Column:  BVOL
# --------------------------------------
# Test Statistic           -2.941793
# p-value                   0.040699
# # Lags                    6.000000
# # Observations          312.000000
# Critical Value (1%)      -3.451484
# Critical Value (5%)      -2.870849
# Critical Value (10%)     -2.571730
# dtype: float64
#
# Series is Stationary
#
#
# Column:  GVOL
# --------------------------------------
# Test Statistic           -3.158556
# p-value                   0.022513
# # Lags                    0.000000
# # Observations          318.000000
# Critical Value (1%)      -3.451082
# Critical Value (5%)      -2.870672
# Critical Value (10%)     -2.571636
# dtype: float64
#
# Series is Stationary
#
#
# Column:  OVOL
# --------------------------------------
# Test Statistic           -1.777428
# p-value                   0.391724
# # Lags                    1.000000
# # Observations          317.000000
# Critical Value (1%)      -3.451148
# Critical Value (5%)      -2.870701
# Critical Value (10%)     -2.571651
# dtype: float64
#
# Series is Non-Stationary
#
#
# Column:  VIX
# --------------------------------------
# Test Statistic           -3.474126
# p-value                   0.008677
# # Lags                    2.000000
# # Observations          316.000000
# Critical Value (1%)      -3.451215
# Critical Value (5%)      -2.870730
# Critical Value (10%)     -2.571666
# dtype: float64
#
# Series is Stationary
#
#
# Column:  btc_price
# --------------------------------------
# Test Statistic         -7.893475e+00
# p-value                 4.373298e-12
# # Lags                  3.000000e+00
# # Observations          3.140000e+02
# Critical Value (1%)    -3.451349e+00
# Critical Value (5%)    -2.870789e+00
# Critical Value (10%)   -2.571698e+00
# dtype: float64
#
# Series is Stationary
#
#
# Column:  gold_price
# --------------------------------------
# Test Statistic          -22.534296
# p-value                   0.000000
# # Lags                    0.000000
# # Observations          317.000000
# Critical Value (1%)      -3.451148
# Critical Value (5%)      -2.870701
# Critical Value (10%)     -2.571651
# dtype: float64
#
# Series is Stationary
#
#
# Column:  oil_wti_price
# --------------------------------------
# Test Statistic          -19.307498
# p-value                   0.000000
# # Lags                    0.000000
# # Observations          317.000000
# Critical Value (1%)      -3.451148
# Critical Value (5%)      -2.870701
# Critical Value (10%)     -2.571651
# dtype: float64
#
# Series is Stationary
#
#
# Column:  sp500_close
# --------------------------------------
# Test Statistic         -1.764403e+01
# p-value                 3.747126e-30
# # Lags                  0.000000e+00
# # Observations          3.170000e+02
# Critical Value (1%)    -3.451148e+00
# Critical Value (5%)    -2.870701e+00
# Critical Value (10%)   -2.571651e+00
# dtype: float64
#
# Series is Stationary
#
#
# Column:  btc_num_trans
# --------------------------------------
# Test Statistic         -1.462938e+01
# p-value                 3.773377e-27
# # Lags                  2.000000e+00
# # Observations          3.150000e+02
# Critical Value (1%)    -3.451281e+00
# Critical Value (5%)    -2.870760e+00
# Critical Value (10%)   -2.571682e+00
# dtype: float64
#
# Series is Stationary
#
#
# Column:  btc_google_search
# --------------------------------------
# Test Statistic         -1.774824e+01
# p-value                 3.378876e-30
# # Lags                  0.000000e+00
# # Observations          3.170000e+02
# Critical Value (1%)    -3.451148e+00
# Critical Value (5%)    -2.870701e+00
# Critical Value (10%)   -2.571651e+00
# dtype: float64
#
# Series is Stationary
#
#
# Column:  btc_dr
# --------------------------------------
# Test Statistic         -7.579280e+00
# p-value                 2.708908e-11
# # Lags                  1.500000e+01
# # Observations          3.020000e+02
# Critical Value (1%)    -3.452190e+00
# Critical Value (5%)    -2.871158e+00
# Critical Value (10%)   -2.571895e+00
# dtype: float64
#
# Series is Stationary
#
#
# Column:  gold_dr
# --------------------------------------
# Test Statistic         -9.246741e+00
# p-value                 1.530202e-15
# # Lags                  1.000000e+01
# # Observations          3.070000e+02
# Critical Value (1%)    -3.451831e+00
# Critical Value (5%)    -2.871001e+00
# Critical Value (10%)   -2.571811e+00
# dtype: float64
#
# Series is Stationary
#
#
# Column:  oil_dr
# --------------------------------------
# Test Statistic         -8.462841e+00
# p-value                 1.550545e-13
# # Lags                  1.500000e+01
# # Observations          3.020000e+02
# Critical Value (1%)    -3.452190e+00
# Critical Value (5%)    -2.871158e+00
# Critical Value (10%)   -2.571895e+00
# dtype: float64
#
# Series is Stationary
#
#
# Column:  sp500_dr
# --------------------------------------
# Test Statistic         -9.882938e+00
# p-value                 3.728297e-17
# # Lags                  1.100000e+01
# # Observations          3.060000e+02
# Critical Value (1%)    -3.451902e+00
# Critical Value (5%)    -2.871032e+00
# Critical Value (10%)   -2.571827e+00
# dtype: float64
#
# Series is Stationary
#
#
# Column:  BVOL
# --------------------------------------
# Test Statistic           -5.217817
# p-value                   0.000008
# # Lags                    5.000000
# # Observations          312.000000
# Critical Value (1%)      -3.451484
# Critical Value (5%)      -2.870849
# Critical Value (10%)     -2.571730
# dtype: float64
#
# Series is Stationary
#
#
# Column:  GVOL
# --------------------------------------
# Test Statistic         -1.817291e+01
# p-value                 2.444342e-30
# # Lags                  0.000000e+00
# # Observations          3.170000e+02
# Critical Value (1%)    -3.451148e+00
# Critical Value (5%)    -2.870701e+00
# Critical Value (10%)   -2.571651e+00
# dtype: float64
#
# Series is Stationary
#
#
# Column:  OVOL
# --------------------------------------
# Test Statistic         -1.196144e+01
# p-value                 4.093384e-22
# # Lags                  0.000000e+00
# # Observations          3.170000e+02
# Critical Value (1%)    -3.451148e+00
# Critical Value (5%)    -2.870701e+00
# Critical Value (10%)   -2.571651e+00
# dtype: float64
#
# Series is Stationary
#
#
# Column:  VIX
# --------------------------------------
# Test Statistic         -1.150315e+01
# p-value                 4.441120e-21
# # Lags                  2.000000e+00
# # Observations          3.150000e+02
# Critical Value (1%)    -3.451281e+00
# Critical Value (5%)    -2.870760e+00
# Critical Value (10%)   -2.571682e+00
# dtype: float64
#
# Series is Stationary
#
#
# Column:  btc_price
# --------------------------------------
# Test Statistic         -7.813370e+00
# p-value                 6.973567e-12
# # Lags                  1.500000e+01
# # Observations          3.010000e+02
# Critical Value (1%)    -3.452263e+00
# Critical Value (5%)    -2.871191e+00
# Critical Value (10%)   -2.571912e+00
# dtype: float64
#
# Series is Stationary
#
#
# Column:  gold_price
# --------------------------------------
# Test Statistic         -9.903284e+00
# p-value                 3.314052e-17
# # Lags                  1.100000e+01
# # Observations          3.050000e+02
# Critical Value (1%)    -3.451974e+00
# Critical Value (5%)    -2.871063e+00
# Critical Value (10%)   -2.571844e+00
# dtype: float64
#
# Series is Stationary
#
#
# Column:  oil_wti_price
# --------------------------------------
# Test Statistic         -8.208999e+00
# p-value                 6.899646e-13
# # Lags                  1.500000e+01
# # Observations          3.010000e+02
# Critical Value (1%)    -3.452263e+00
# Critical Value (5%)    -2.871191e+00
# Critical Value (10%)   -2.571912e+00
# dtype: float64
#
# Series is Stationary
# Column:  sp500_close
# --------------------------------------
# Test Statistic         -9.845571e+00
# p-value                 4.629526e-17
# # Lags                  1.100000e+01
# # Observations          3.050000e+02
# Critical Value (1%)    -3.451974e+00
# Critical Value (5%)    -2.871063e+00
# Critical Value (10%)   -2.571844e+00
# dtype: float64
#
# Series is Stationary
#
#
# Column:  btc_num_trans
# --------------------------------------
# Test Statistic         -7.869854e+00
# p-value                 5.018927e-12
# # Lags                  1.600000e+01
# # Observations          3.000000e+02
# Critical Value (1%)    -3.452337e+00
# Critical Value (5%)    -2.871223e+00
# Critical Value (10%)   -2.571929e+00
# dtype: float64
#
# Series is Stationary
#
#
# Column:  btc_google_search
# --------------------------------------
# Test Statistic         -8.954430e+00
# p-value                 8.549901e-15
# # Lags                  1.000000e+01
# # Observations          3.060000e+02
# Critical Value (1%)    -3.451902e+00
# Critical Value (5%)    -2.871032e+00
# Critical Value (10%)   -2.571827e+00
# dtype: float64
#
# Series is Stationary
#
#
# Column:  btc_dr
# --------------------------------------
# Test Statistic         -8.652531e+00
# p-value                 5.069833e-14
# # Lags                  1.600000e+01
# # Observations          3.000000e+02
# Critical Value (1%)    -3.452337e+00
# Critical Value (5%)    -2.871223e+00
# Critical Value (10%)   -2.571929e+00
# dtype: float64
#
# Series is Stationary
#
#
# Column:  gold_dr
# --------------------------------------
# Test Statistic         -9.177034e+00
# p-value                 2.305265e-15
# # Lags                  1.700000e+01
# # Observations          2.990000e+02
# Critical Value (1%)    -3.452411e+00
# Critical Value (5%)    -2.871255e+00
# Critical Value (10%)   -2.571947e+00
# dtype: float64
#
# Series is Stationary
#
#
# Column:  oil_dr
# --------------------------------------
# Test Statistic         -1.043435e+01
# p-value                 1.580612e-18
# # Lags                  1.600000e+01
# # Observations          3.000000e+02
# Critical Value (1%)    -3.452337e+00
# Critical Value (5%)    -2.871223e+00
# Critical Value (10%)   -2.571929e+00
# dtype: float64
#
# Series is Stationary
#
#
# Column:  sp500_dr
# --------------------------------------
# Test Statistic         -9.499415e+00
# p-value                 3.477545e-16
# # Lags                  1.600000e+01
# # Observations          3.000000e+02
# Critical Value (1%)    -3.452337e+00
# Critical Value (5%)    -2.871223e+00
# Critical Value (10%)   -2.571929e+00
# dtype: float64
#
# Series is Stationary
#
#
# Column:  BVOL
# --------------------------------------
# Test Statistic         -1.218251e+01
# p-value                 1.341514e-22
# # Lags                  5.000000e+00
# # Observations          3.110000e+02
# Critical Value (1%)    -3.451553e+00
# Critical Value (5%)    -2.870879e+00
# Critical Value (10%)   -2.571746e+00
# dtype: float64
#
# Series is Stationary
#
#
# Column:  GVOL
# --------------------------------------
# Test Statistic         -8.288705e+00
# p-value                 4.319941e-13
# # Lags                  1.200000e+01
# # Observations          3.040000e+02
# Critical Value (1%)    -3.452045e+00
# Critical Value (5%)    -2.871095e+00
# Critical Value (10%)   -2.571861e+00
# dtype: float64
#
# Series is Stationary
#
#
# Column:  OVOL
# --------------------------------------
# Test Statistic         -7.609087e+00
# p-value                 2.280410e-11
# # Lags                  1.500000e+01
# # Observations          3.010000e+02
# Critical Value (1%)    -3.452263e+00
# Critical Value (5%)    -2.871191e+00
# Critical Value (10%)   -2.571912e+00
# dtype: float64
#
# Series is Stationary
#
#
# Column:  VIX
# --------------------------------------
# Test Statistic         -9.259527e+00
# p-value                 1.419452e-15
# # Lags                  1.100000e+01
# # Observations          3.050000e+02
# Critical Value (1%)    -3.451974e+00
# Critical Value (5%)    -2.871063e+00
# Critical Value (10%)   -2.571844e+00
# dtype: float64
#
# Series is Stationary

# %% [markdown]
# ## Result:
# <b> Time Invariant Columns(Stationary) -</b>
# <i>btc_dr, gold_dr, oil_dr, sp500_dr, BVOL, GVOL, VIX</i>
#
# <b>Time Dependent Columns(non- stationary) -</b>
# <i>btc_price, gold_price, oil_wti_price, sp500_close, btc_num_trans, btc_google_search, OVOL</i>
#
# ------------------------------------------------------------------------
#
# ## Note :**First order differencing makes all non-stationary columns Stationary**
